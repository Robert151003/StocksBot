# %% [markdown]
# ## <u>**1 - Importing Test Data & Testing** </u>
#
# This section focuses on the initial setup, data acquisition, and the core logic for generating trading signals based on candlestick reversal patterns. It covers:
#
# -   **Data Download**: Downloads 15-minute candlestick data for the EUR/USD forex pair using Yahoo Finance.
# -   **Pattern Detection Logic (`signal_generator`)**: Defines a Python function to identify specific candlestick reversal patterns. The patterns currently implemented are:
#     -   **Bullish Engulfing**: A strong reversal pattern indicating a potential price increase (Buy Signal).
#     -   **Bearish Engulfing**: A strong reversal pattern indicating a potential price decrease (Sell Signal).
#     -   **Morning Star**: A three-candle bullish reversal pattern (Buy Signal).
#     -   **Three White Soldiers**: A strong bullish reversal/continuation pattern over four candles (Buy Signal).
#     -   **Doji**: A neutral candle indicating indecision (No Pattern/No Trade).
# -   **Signal Generation**: Applies the `signal_generator` function across the downloaded dataset to create a new `signal` column.
#     -   `0` = No pattern detected
#     -   `1` = Buy signal
#     -   `2` = Sell signal
# -   **Output Utilization**: The generated `signal` column can be used for backtesting trading strategies or as an input for an automated trading system.

# %%
import yfinance as yf
import pandas as pd

dataF = yf.download("EURUSD=X", start="2025-7-15", end="2025-7-23", interval='5m')
dataF.iloc[:, :]
# Out:
# C:\Users\Robert\AppData\Local\Temp\ipykernel_38204\1980669582.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dataF = yf.download("EURUSD=X", start="2025-7-15", end="2025-7-23", interval='5m')
# [*********************100%***********************]  1 of 1 completed
# Price                         Close      High       Low      Open   Volume
# Ticker                     EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Datetime
# 2025-07-14 23:00:00+00:00  1.166861  1.166997  1.166861  1.166861        0
# 2025-07-14 23:05:00+00:00  1.166861  1.166861  1.166725  1.166725        0
# 2025-07-14 23:10:00+00:00  1.166725  1.166861  1.166725  1.166861        0
# 2025-07-14 23:15:00+00:00  1.166589  1.166725  1.166589  1.166725        0
# 2025-07-14 23:20:00+00:00  1.166453  1.166589  1.166453  1.166589        0
# ...                             ...       ...       ...       ...      ...
# 2025-07-22 22:35:00+00:00  1.175226  1.175226  1.175088  1.175088        0
# 2025-07-22 22:40:00+00:00  1.175364  1.175364  1.175226  1.175226        0
# 2025-07-22 22:45:00+00:00  1.175364  1.175364  1.175226  1.175364        0
# 2025-07-22 22:50:00+00:00  1.175226  1.175364  1.175226  1.175226        0
# 2025-07-22 22:55:00+00:00  1.175226  1.175226  1.175226  1.175226        0
#
# [1710 rows x 5 columns]

# %%
import logging

# Logging for heartbeat
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("bot_heartbeat.log"), # Log to a file
    ]
)

# %%
def signal_generator(df):

    # Safely extract candle data, initializing older candles to None if not available
    open_c = df['Open'].iloc[-1]
    close_c = df['Close'].iloc[-1]
    high_c = df['High'].iloc[-1]
    low_c = df['Low'].iloc[-1]
    
    open_p = df['Open'].iloc[-2]
    close_p = df['Close'].iloc[-2]
    high_p = df['High'].iloc[-2]
    low_p = df['Low'].iloc[-2]

    open_pp = None # previous previous candle
    close_pp = None
    high_pp = None
    low_pp = None

    open_ppp = None # previous previous previous candle
    close_ppp = None
    high_ppp = None
    low_ppp = None

    # Populate older candle data only if enough rows exist
    if len(df) >= 3:
        open_pp = df['Open'].iloc[-3]
        close_pp = df['Close'].iloc[-3]
        high_pp = df['High'].iloc[-3]
        low_pp = df['Low'].iloc[-3]
    if len(df) >= 4:
        open_ppp = df['Open'].iloc[-4]
        close_ppp = df['Close'].iloc[-4]
        high_ppp = df['High'].iloc[-4]
        low_ppp = df['Low'].iloc[-4]


    # --- Bullish Engulfing Pattern (Buy Signal: 1) ---
    # Current candle is bullish AND its body completely engulfs the previous bearish candle's body
    if (close_c > open_c and        # Current candle is bullish
        close_p < open_p and        # Previous candle was bearish
        close_c > open_p and        # Current close is higher than previous open (engulfs top)
        open_c < close_p):          # Current open is lower than previous close (engulfs bottom)
        logging.debug(f"Bullish Engulfing detected: C({open_c:.5f},{close_c:.5f}) P({open_p:.5f},{close_p:.5f})")
        return 1 # Buy Signal

    # --- Bearish Engulfing Pattern (Sell Signal: 2) ---
    # Current candle is bearish AND its body completely engulfs the previous bullish candle's body
    elif (close_c < open_c and       # Current candle is bearish
          close_p > open_p and       # Previous candle was bullish
          open_c > close_p and       # Current open is higher than previous close (engulfs top)
          close_c < open_p):         # Current close is lower than previous open (engulfs bottom)
        logging.debug(f"Bearish Engulfing detected: C({open_c:.5f},{close_c:.5f}) P({open_p:.5f},{close_p:.5f})")
        return 2 

    # --- Morning Star Pattern (Bullish Reversal: Buy Signal: 1) ---
    # Requires 3 candles:
    # 1. Long bearish candle (previous_previous_candle)
    # 2. Small-bodied candle (could be Doji, bullish or bearish) that gaps down or is below 1st's body
    # 3. Long bullish candle (current_candle) that gaps up or is above 2nd's body and closes well into the body of the first candle
    elif (open_pp is not None and                                # Ensure 3rd candle (index -3) exists
          close_pp < open_pp and                                 # 1st candle (ppp) is bearish
          abs(open_p - close_p) < (high_p - low_p) * 0.5 and    # 2nd candle (p) has small body (e.g., Doji or spinning top)
          max(close_p, open_p) < open_pp and                     # 2nd candle's body is below 1st candle's open (gaps down)
          close_c > open_c and                                  # 3rd candle (c) is bullish
          open_c > max(close_p, open_p) and                     # 3rd candle opens above 2nd candle's body (gaps up)
          close_c > (open_pp + close_pp) / 2):                  # 3rd candle closes more than halfway into 1st's body
        logging.debug(f"Morning Star detected: C({open_c:.5f},{close_c:.5f}) P({open_p:.5f},{close_p:.5f}) PP({open_pp:.5f},{close_pp:.5f})")
        return 1

    # --- Three White Soldiers Pattern (Bullish Reversal/Continuation: Buy Signal: 1) ---
    # Requires 4 candles:
    # 1. Long bearish candle (ppp) typically precedes it (though not strictly part of the pattern definition itself, common context)
    # 2. Bullish candle (pp) opens within or near body of ppp, closes higher
    # 3. Bullish candle (p) opens within or near body of pp, closes higher
    # 4. Bullish candle (c) opens within or near body of p, closes higher
    elif (open_ppp is not None and                                # Ensure 4th candle (index -4) exists
          # Optional: close_ppp < open_ppp and                     # 1st candle (ppp) is bearish (context)
          close_pp > open_pp and                                  # 2nd candle (pp) is bullish
          open_pp > min(open_ppp, close_ppp) and open_pp < max(open_ppp, close_ppp) and # 2nd opens within or above 1st's body
          close_p > open_p and                                    # 3rd candle (p) is bullish
          open_p > min(open_pp, close_pp) and open_p < max(open_pp, close_pp) and     # 3rd opens within or above 2nd's body
          close_c > open_c and                                    # 4th candle (c) is bullish
          open_c > min(open_p, close_p) and open_c < max(open_p, close_p)):         # 4th opens within or above 3rd's body
        logging.debug(f"Three White Soldiers detected: C({open_c:.5f},{close_c:.5f}) P({open_p:.5f},{close_p:.5f}) PP({open_pp:.5f},{close_pp:.5f}) PPP({open_ppp:.5f},{close_ppp:.5f})")
        return 1

    # --- Doji Pattern (Neutral / No Pattern: 0) ---
    # A candle where the open and close prices are very close, indicating indecision.
    elif abs(open_c - close_c) < (high_c - low_c) * 0.05:
        logging.debug(f"Doji detected, returning 0 (Close: {close_c:.5f})")
        return 0

    # No Specific Pattern Detected
    else:
        return 0

# %%
# Flatten columns if MultiIndex (e.g., after yfinance download)
if isinstance(dataF.columns, pd.MultiIndex):
    dataF.columns = dataF.columns.get_level_values(0)

# We need 4 candles for the 'Three White Soldiers' pattern (iloc[-1] to iloc[-4]).
# So, the loop starts from index 3 to ensure dataF[i-3] is valid.
# The first 3 signals (for indices 0, 1, 2) will be 0 as there's not enough preceding data.
REQUIRED_CANDLES_FOR_LARGEST_PATTERN = 4
signal = [0] * (REQUIRED_CANDLES_FOR_LARGEST_PATTERN - 1) # Pre-fill with 3 zeros for indices 0, 1, 2

for i in range(REQUIRED_CANDLES_FOR_LARGEST_PATTERN - 1, len(dataF)):
    # Slice to get 4 candles: dataF[i-3], dataF[i-2], dataF[i-1], dataF[i]
    df = dataF[i-(REQUIRED_CANDLES_FOR_LARGEST_PATTERN-1):i+1]
    signal.append(signal_generator(df))

dataF['signal'] = signal
dataF.signal.value_counts()
# Out:
# signal
# 0    1692
# 1      14
# 2       4
# Name: count, dtype: int64

# %% [markdown]
# ## <u>**2 - Connect to live trading service**</u>
#
# This section establishes the connection to the OANDA live trading service and sets up the automated trading logic. It covers:
#
# -   **Configuration**: Defines mappings for trading intervals (`M1`, `M5`, etc.) to OANDA's granularity and cron schedule settings. It also loads sensitive API credentials (access token and account ID) securely from environment variables using `python-dotenv`.
# -   **Data Acquisition**: Implements a `get_candles` function to retrieve live candlestick data for EUR/USD from OANDA.
# -   **Monitoring**: Includes a utility function (`get_memory_usage_mb`) to monitor the bot's memory usage during operation, aiding in performance and stability checks.
# -   **Trade Execution Logic (`trading_job`)**: This core function is scheduled to run periodically and performs the following steps:
#     -   Logs current memory usage.
#     -   Fetches the latest candlestick data.
#     -   Converts the live candle data into a Pandas DataFrame.
#     -   Generates a trading `signal` (buy, sell, or no action) using the `signal_generator` function defined in Section 1.
#     -   Calculates **Take Profit (TP)** and **Stop Loss (SL)** levels dynamically based on recent price action to manage risk.
#     -   Places market orders (buy or sell) with attached TP/SL orders via the OANDA API if an actionable signal is detected.
#     -   Logs all trading decisions and API responses.
#     -   Includes robust error handling, triggering an `emergency_stop` in case of critical failures.
# -   **Emergency Stop**: Provides `close_all_positions` and `emergency_stop` functions to immediately close any open positions and shut down the trading bot, offering a critical safety mechanism.
# -   **Scheduling**: Utilizes `APScheduler` to run the `trading_job` automatically at predefined intervals (e.g., every 5 minutes for 'M5' trading interval) during weekdays.
# -   **Interactive Control**: Presents an "EMERGENCY STOP" button using `ipywidgets` for manual intervention to stop the bot and close all positions instantly.

# %%
from apscheduler.schedulers.blocking import BlockingScheduler
from oandapyV20 import API
import oandapyV20.endpoints.orders as orders
from oandapyV20.contrib.requests import MarketOrderRequest
from oanda_candles import Pair, Gran, CandleClient
from oandapyV20.contrib.requests import TakeProfitDetails, StopLossDetails

# %%
from oanda_candles import Gran

INTERVAL_MAP = {
    "M1": Gran.M1,
    "M5": Gran.M5,
    "M15": Gran.M15,
    "M30": Gran.M30,
    "H1": Gran.H1,
    "H4": Gran.H4,
    "D": Gran.D
}

SCHEDULER_MINUTE_MAP = {
    "M1": "*",    # Every minute
    "M5": "*/5",  # Every 5th minute
    "M15": "*/15", # Every 15th minute
    "M30": "*/30", # Every 30th minute
    "H1": "1",    # Minute 1 of every hour (hourly)
    "H4": "1",    # Minute 1 of every hour (hourly, for 4-hour candles)
    "D": "1"      # Minute 1 of every hour (hourly, for daily candles)
}

# %%
import psutil
import os

def get_memory_usage_mb():
    """Returns memory usage of the current process in MB."""
    process = psutil.Process(os.getpid())
    mem_info = process.memory_info()
    return mem_info.rss / (1024 * 1024) # Resident Set Size in MB

# %%
from dotenv import load_dotenv

load_dotenv()  # Loads variables from .env

access_token = os.getenv("OANDA_API_KEY")
accountID = os.getenv("OANDA_ACCOUNT_ID")
trading_interval_str = os.getenv("TRADING_INTERVAL", "M5")

# %%
def get_candles(n):
    trading_interval_str = os.getenv("TRADING_INTERVAL", "M5") # Default to M1 if not set
    granularity = INTERVAL_MAP.get(trading_interval_str, Gran.M5)

    client = CandleClient(access_token, real=False)
    collector = client.get_collector(Pair.EUR_USD, granularity)
    candles = collector.grab(n)
    return candles

candles = get_candles(10)
for candle in candles:
    print(float(str(candle.bid.o))>1)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
scheduler = BlockingScheduler()

# %%
import oandapyV20.endpoints.positions as positions

def close_all_positions():
    client = API(access_token)
    # This closes all open positions for EUR/USD
    data = {
        "longUnits": "ALL",   # Close all long positions
        "shortUnits": "ALL"   # Close all short positions
    }
    r = positions.PositionClose(accountID, instrument="EUR_USD", data=data)
    response = client.request(r)
    print("All positions closed:", response)

# %%
def emergency_stop():
    close_all_positions()
    scheduler.shutdown()
    print("All positions closed and bot stopped.")

# %%
def trading_job():
    logging.info("--- Trading job started ---")
    
    try:
        current_memory_mb = get_memory_usage_mb()
        logging.info(f"Current memory usage: {current_memory_mb:.2f} MB")
    except NameError:
        logging.warning("get_memory_usage_mb function not found. Skipping memory logging.")
    except Exception as e:
        logging.warning(f"Error getting memory usage: {e}")

    try:
        candles = get_candles(10)

        if not candles:
            logging.warning("No candles received. Skipping trading decision.")
            return # Exit the job if no candles

        if len(candles) < 10:
            logging.warning(f"Only {len(candles)} candles received. Need at least 10 for flexible pattern analysis. Skipping trading decision.")
            return # Exit if not enough candles

        dfstream = pd.DataFrame(columns=['Open', 'Close', 'High', 'Low'])

        i=0
        for candle in candles:
            dfstream.loc[i, ['Open']] = float(str(candle.bid.o))
            dfstream.loc[i, ['Close']] = float(str(candle.bid.c))
            dfstream.loc[i, ['High']] = float(str(candle.bid.h))
            dfstream.loc[i, ['Low']] = float(str(candle.bid.l))
            i=i+1
        
        dfstream['Open'] = dfstream['Open'].astype(float)
        dfstream['Close'] = dfstream['Close'].astype(float)
        dfstream['High'] = dfstream['High'].astype(float)
        dfstream['Low'] = dfstream['Low'].astype(float)

        if dfstream.isnull().values.any():
            logging.error("DataFrame contains NaN values after conversion. Skipping trading decision.")
            return

        signal = signal_generator(dfstream.iloc[:-1, :])

        client = API(access_token)

        SLTPRatio = 2
        previous_candleR = abs(dfstream['High'].iloc[-2]-dfstream['Low'].iloc[-2]) 

        current_open_price = dfstream['Open'].iloc[-1]
        SLBuy = current_open_price - previous_candleR
        SLSell = current_open_price + previous_candleR
        TPBuy = current_open_price + previous_candleR * SLTPRatio
        TPSell = current_open_price - previous_candleR * SLTPRatio

        logging.info(f"DataFrame for signal (last 2 candles shown):\\n{dfstream.iloc[:-1, :].tail(2)}")
        logging.info(f"Calculated TP/SL: TPBuy={TPBuy:.5f}, SLBuy={SLBuy:.5f}, TPSell={TPSell:.5f}, SLSell={SLSell:.5f}")
        logging.info(f"Generated Trading Signal: {signal}")

        # Sell
        if signal == 1:
            logging.info("SELL signal detected. Attempting to place order.")
            mo = MarketOrderRequest(instrument="EUR_USD", units=-1000, 
                                    takeProfitOnFill=TakeProfitDetails(price=str(TPSell)).data, 
                                    stopLossOnFill=StopLossDetails(price=str(SLSell)).data)
            r = orders.OrderCreate(accountID, data=mo.data)
            rv = client.request(r)
            logging.info(f"Sell Order Response: {rv}")
        
        # Buy
        elif signal == 2:
            logging.info("BUY signal detected. Attempting to place order.")
            mo = MarketOrderRequest(instrument="EUR_USD", units=1000, 
                                    takeProfitOnFill=TakeProfitDetails(price=str(TPBuy)).data, 
                                    stopLossOnFill=StopLossDetails(price=str(SLBuy)).data)
            r = orders.OrderCreate(accountID, data=mo.data)
            rv = client.request(r)
            logging.info(f"Buy Order Response: {rv}")
        
        # No Pattern
        else:
            logging.info("No actionable trading signal (0). No order placed.")

    except Exception as e:
        logging.exception("Critical error in trading_job! Triggering emergency stop.")
        try:
            emergency_stop()
        except NameError:
            logging.error("Emergency stop function not found. Please ensure 'emergency_stop()' is defined.")
            pass
        except Exception as es_e:
            logging.exception(f"Error during emergency_stop execution: {es_e}")

# %%
import ipywidgets as widgets
from IPython.display import display

button = widgets.Button(description="EMERGENCY STOP", button_style='danger')

def on_button_clicked(b):
    emergency_stop()

button.on_click(on_button_clicked)
display(button)
# Out:
# Button(button_style='danger', description='EMERGENCY STOP', style=ButtonStyle())

# %% [markdown]
# ## <u>**3 - Calling Functions**</u>
#
# This section outlines how the automated trading bot's core functionality is initiated and managed through a scheduled job. It specifically details:
#
# -   **Scheduler Initialization**: Initializes a `BlockingScheduler` from `APScheduler` to manage the execution of the trading job.
# -   **Dynamic Scheduling**: Configures the `trading_job` to run automatically at specific intervals using a cron-like schedule. The frequency of execution (`minute` setting) is dynamically determined based on the `TRADING_INTERVAL` environment variable (e.g., every 5 minutes for 'M5' candles).
# -   **Operational Hours**: The job is set to run only on weekdays, from midnight to 11 PM UTC, aligning with typical forex market hours.
# -   **Timezone Management**: The scheduler is configured with the 'Europe/London' timezone to ensure accurate timing of job execution.
# -   **Bot Activation**: Starts the scheduler, putting the automated trading system into operation, continuously monitoring for signals and executing trades as programmed.

# %%
scheduler_minute_setting = SCHEDULER_MINUTE_MAP.get(trading_interval_str, "*")

scheduler.add_job(
    trading_job,
    'cron',
    day_of_week='mon-fri',
    hour='00-23',
    minute=scheduler_minute_setting,
    start_date='2025-07-23 12:00:00',
    timezone='Europe/London'
)

logging.info("Scheduler started.")
scheduler.start()
# Out:
# 2025-07-24 14:32:58,911 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2025-07-24 14:32:58,912 - INFO - Scheduler started.
# 2025-07-24 14:32:58,913 - INFO - Added job "trading_job" to job store "default"
# 2025-07-24 14:32:58,914 - INFO - Scheduler started
# 2025-07-24 14:35:00,009 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:40:00 BST)" (scheduled at 2025-07-24 14:35:00+01:00)
# 2025-07-24 14:35:00,011 - INFO - --- Trading job started ---
# 2025-07-24 14:35:00,012 - INFO - Current memory usage: 152.30 MB
# 2025-07-24 14:35:00,358 - INFO - setting up API-client for environment practice
# 2025-07-24 14:35:00,360 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17605  1.17686  1.17723  1.17595
# 8  1.17689  1.17625  1.17729  1.17622
# 2025-07-24 14:35:00,360 - INFO - Calculated TP/SL: TPBuy=1.17837, SLBuy=1.17516, TPSell=1.17409, SLSell=1.17730
# 2025-07-24 14:35:00,361 - INFO - Generated Trading Signal: 0
# 2025-07-24 14:35:00,362 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 14:35:00,362 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:40:00 BST)" executed successfully
# 2025-07-24 14:40:00,013 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:45:00 BST)" (scheduled at 2025-07-24 14:40:00+01:00)
# 2025-07-24 14:40:00,014 - INFO - --- Trading job started ---
# 2025-07-24 14:40:00,014 - INFO - Current memory usage: 152.47 MB
# 2025-07-24 14:40:00,205 - INFO - setting up API-client for environment practice
# 2025-07-24 14:40:00,207 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17605  1.17686  1.17723  1.17595
# 8  1.17689  1.17625  1.17729  1.17622
# 2025-07-24 14:40:00,208 - INFO - Calculated TP/SL: TPBuy=1.17837, SLBuy=1.17516, TPSell=1.17409, SLSell=1.17730
# 2025-07-24 14:40:00,209 - INFO - Generated Trading Signal: 0
# 2025-07-24 14:40:00,209 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 14:40:00,210 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:45:00 BST)" executed successfully
# 2025-07-24 14:45:00,004 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:50:00 BST)" (scheduled at 2025-07-24 14:45:00+01:00)
# 2025-07-24 14:45:00,005 - INFO - --- Trading job started ---
# 2025-07-24 14:45:00,006 - INFO - Current memory usage: 149.05 MB
# 2025-07-24 14:45:00,569 - INFO - setting up API-client for environment practice
# 2025-07-24 14:45:00,571 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17623  1.17636  1.17687  1.17605
# 8  1.17639  1.17623  1.17655  1.17603
# 2025-07-24 14:45:00,572 - INFO - Calculated TP/SL: TPBuy=1.17723, SLBuy=1.17567, TPSell=1.17515, SLSell=1.17671
# 2025-07-24 14:45:00,572 - INFO - Generated Trading Signal: 0
# 2025-07-24 14:45:00,573 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 14:45:00,574 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:50:00 BST)" executed successfully
# 2025-07-24 14:50:00,002 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:55:00 BST)" (scheduled at 2025-07-24 14:50:00+01:00)
# 2025-07-24 14:50:00,003 - INFO - --- Trading job started ---
# 2025-07-24 14:50:00,004 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 14:50:00,748 - INFO - setting up API-client for environment practice
# 2025-07-24 14:50:00,751 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17639  1.17623  1.17655  1.17603
# 8  1.17619  1.17704  1.17710  1.17550
# 2025-07-24 14:50:00,751 - INFO - Calculated TP/SL: TPBuy=1.18026, SLBuy=1.17546, TPSell=1.17386, SLSell=1.17866
# 2025-07-24 14:50:00,752 - INFO - Generated Trading Signal: 1
# 2025-07-24 14:50:00,753 - INFO - SELL signal detected. Attempting to place order.
# 2025-07-24 14:50:00,754 - INFO - performing request https://api-fxpractice.oanda.com/v3/accounts/101-004-35883351-001/orders
# 2025-07-24 14:50:00,969 - INFO - Sell Order Response: {'orderCreateTransaction': {'id': '235', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '235', 'requestID': '115440536896968937', 'time': '2025-07-24T13:50:01.961540927Z', 'type': 'MARKET_ORDER', 'instrument': 'EUR_USD', 'units': '-1000', 'timeInForce': 'FOK', 'positionFill': 'DEFAULT', 'takeProfitOnFill': {'price': '1.17386', 'timeInForce': 'GTC'}, 'stopLossOnFill': {'price': '1.17866', 'timeInForce': 'GTC', 'triggerMode': 'TOP_OF_BOOK'}, 'reason': 'CLIENT_ORDER'}, 'orderFillTransaction': {'id': '236', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '235', 'requestID': '115440536896968937', 'time': '2025-07-24T13:50:01.961540927Z', 'type': 'ORDER_FILL', 'orderID': '235', 'instrument': 'EUR_USD', 'units': '-1000', 'requestedUnits': '-1000', 'price': '1.17717', 'pl': '0.0000', 'quotePL': '0', 'financing': '0.0000', 'baseFinancing': '0', 'commission': '0.0000', 'accountBalance': '100007.2186', 'gainQuoteHomeConversionFactor': '0.73434986375', 'lossQuoteHomeConversionFactor': '0.741730264391', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0258', 'fullVWAP': '1.17717', 'reason': 'MARKET_ORDER', 'tradeOpened': {'price': '1.17717', 'tradeID': '236', 'units': '-1000', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0258', 'initialMarginRequired': '28.9613'}, 'fullPrice': {'closeoutBid': '1.17708', 'closeoutAsk': '1.17734', 'timestamp': '2025-07-24T13:50:01.925759054Z', 'bids': [{'price': '1.17717', 'liquidity': '500000'}, {'price': '1.17716', 'liquidity': '500000'}, {'price': '1.17715', 'liquidity': '2000000'}, {'price': '1.17714', 'liquidity': '2000000'}, {'price': '1.17713', 'liquidity': '5000000'}, {'price': '1.17711', 'liquidity': '10000000'}, {'price': '1.17708', 'liquidity': '10000000'}], 'asks': [{'price': '1.17724', 'liquidity': '500000'}, {'price': '1.17726', 'liquidity': '2500000'}, {'price': '1.17727', 'liquidity': '2000000'}, {'price': '1.17728', 'liquidity': '5000000'}, {'price': '1.17731', 'liquidity': '10000000'}, {'price': '1.17734', 'liquidity': '10000000'}]}, 'homeConversionFactors': {'gainQuoteHome': {'factor': '0.73434986375045'}, 'lossQuoteHome': {'factor': '0.74173026439115'}, 'gainBaseHome': {'factor': '0.86449580'}, 'lossBaseHome': {'factor': '0.87318420'}}}, 'relatedTransactionIDs': ['235', '236', '237', '238'], 'lastTransactionID': '238'}
# 2025-07-24 14:50:00,970 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 14:55:00 BST)" executed successfully
# 2025-07-24 14:55:00,009 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:00:00 BST)" (scheduled at 2025-07-24 14:55:00+01:00)
# 2025-07-24 14:55:00,010 - INFO - --- Trading job started ---
# 2025-07-24 14:55:00,011 - INFO - Current memory usage: 149.12 MB
# 2025-07-24 14:55:00,227 - INFO - setting up API-client for environment practice
# 2025-07-24 14:55:00,229 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17619  1.17704  1.17710  1.17550
# 8  1.17706  1.17758  1.17761  1.17702
# 2025-07-24 14:55:00,230 - INFO - Calculated TP/SL: TPBuy=1.17877, SLBuy=1.17700, TPSell=1.17641, SLSell=1.17818
# 2025-07-24 14:55:00,230 - INFO - Generated Trading Signal: 0
# 2025-07-24 14:55:00,230 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 14:55:00,231 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:00:00 BST)" executed successfully
# 2025-07-24 15:00:00,015 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:05:00 BST)" (scheduled at 2025-07-24 15:00:00+01:00)
# 2025-07-24 15:00:00,016 - INFO - --- Trading job started ---
# 2025-07-24 15:00:00,017 - INFO - Current memory usage: 149.00 MB
# 2025-07-24 15:00:00,784 - INFO - setting up API-client for environment practice
# 2025-07-24 15:00:00,786 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17706  1.17758  1.17761  1.17702
# 8  1.17759  1.17706  1.17761  1.17698
# 2025-07-24 15:00:00,786 - INFO - Calculated TP/SL: TPBuy=1.17831, SLBuy=1.17642, TPSell=1.17579, SLSell=1.17768
# 2025-07-24 15:00:00,787 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:00:00,787 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:00:00,788 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:05:00 BST)" executed successfully
# 2025-07-24 15:05:00,006 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:10:00 BST)" (scheduled at 2025-07-24 15:05:00+01:00)
# 2025-07-24 15:05:00,007 - INFO - --- Trading job started ---
# 2025-07-24 15:05:00,008 - INFO - Current memory usage: 149.02 MB
# 2025-07-24 15:05:00,197 - INFO - setting up API-client for environment practice
# 2025-07-24 15:05:00,199 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17759  1.17706  1.17761  1.17698
# 8  1.17705  1.17842  1.17867  1.17704
# 2025-07-24 15:05:00,200 - INFO - Calculated TP/SL: TPBuy=1.18167, SLBuy=1.17678, TPSell=1.17515, SLSell=1.18004
# 2025-07-24 15:05:00,200 - INFO - Generated Trading Signal: 1
# 2025-07-24 15:05:00,201 - INFO - SELL signal detected. Attempting to place order.
# 2025-07-24 15:05:00,202 - INFO - performing request https://api-fxpractice.oanda.com/v3/accounts/101-004-35883351-001/orders
# 2025-07-24 15:05:00,364 - INFO - Sell Order Response: {'orderCreateTransaction': {'id': '241', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '241', 'requestID': '79411743650831306', 'time': '2025-07-24T14:05:01.369438382Z', 'type': 'MARKET_ORDER', 'instrument': 'EUR_USD', 'units': '-1000', 'timeInForce': 'FOK', 'positionFill': 'DEFAULT', 'takeProfitOnFill': {'price': '1.17515', 'timeInForce': 'GTC'}, 'stopLossOnFill': {'price': '1.18004', 'timeInForce': 'GTC', 'triggerMode': 'TOP_OF_BOOK'}, 'reason': 'CLIENT_ORDER'}, 'orderFillTransaction': {'id': '242', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '241', 'requestID': '79411743650831306', 'time': '2025-07-24T14:05:01.369438382Z', 'type': 'ORDER_FILL', 'orderID': '241', 'instrument': 'EUR_USD', 'units': '-1000', 'requestedUnits': '-1000', 'price': '1.17843', 'pl': '0.0000', 'quotePL': '0', 'financing': '0.0000', 'baseFinancing': '0', 'commission': '0.0000', 'accountBalance': '100006.1069', 'gainQuoteHomeConversionFactor': '0.733900296057', 'lossQuoteHomeConversionFactor': '0.741276178429', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0258', 'fullVWAP': '1.17843', 'reason': 'MARKET_ORDER', 'tradeOpened': {'price': '1.17843', 'tradeID': '242', 'units': '-1000', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0258', 'initialMarginRequired': '28.9743'}, 'fullPrice': {'closeoutBid': '1.17834', 'closeoutAsk': '1.17860', 'timestamp': '2025-07-24T14:05:00.588996440Z', 'bids': [{'price': '1.17843', 'liquidity': '500000'}, {'price': '1.17842', 'liquidity': '500000'}, {'price': '1.17841', 'liquidity': '2000000'}, {'price': '1.17840', 'liquidity': '2000000'}, {'price': '1.17839', 'liquidity': '5000000'}, {'price': '1.17837', 'liquidity': '10000000'}, {'price': '1.17834', 'liquidity': '10000000'}], 'asks': [{'price': '1.17850', 'liquidity': '500000'}, {'price': '1.17852', 'liquidity': '2500000'}, {'price': '1.17853', 'liquidity': '2000000'}, {'price': '1.17854', 'liquidity': '5000000'}, {'price': '1.17857', 'liquidity': '10000000'}, {'price': '1.17860', 'liquidity': '10000000'}]}, 'homeConversionFactors': {'gainQuoteHome': {'factor': '0.73390029605661'}, 'lossQuoteHome': {'factor': '0.74127617842903'}, 'gainBaseHome': {'factor': '0.86488385'}, 'lossBaseHome': {'factor': '0.87357615'}}}, 'relatedTransactionIDs': ['241', '242', '243', '244'], 'lastTransactionID': '244'}
# 2025-07-24 15:05:00,365 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:10:00 BST)" executed successfully
# 2025-07-24 15:10:00,003 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:15:00 BST)" (scheduled at 2025-07-24 15:10:00+01:00)
# 2025-07-24 15:10:00,004 - INFO - --- Trading job started ---
# 2025-07-24 15:10:00,005 - INFO - Current memory usage: 149.04 MB
# 2025-07-24 15:10:00,325 - INFO - setting up API-client for environment practice
# 2025-07-24 15:10:00,327 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17705  1.17842  1.17867  1.17704
# 8  1.17841  1.17807  1.17880  1.17800
# 2025-07-24 15:10:00,328 - INFO - Calculated TP/SL: TPBuy=1.17967, SLBuy=1.17727, TPSell=1.17647, SLSell=1.17887
# 2025-07-24 15:10:00,328 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:10:00,329 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:10:00,329 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:15:00 BST)" executed successfully
# 2025-07-24 15:15:00,001 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:20:00 BST)" (scheduled at 2025-07-24 15:15:00+01:00)
# 2025-07-24 15:15:00,002 - INFO - --- Trading job started ---
# 2025-07-24 15:15:00,002 - INFO - Current memory usage: 149.02 MB
# 2025-07-24 15:15:00,237 - INFO - setting up API-client for environment practice
# 2025-07-24 15:15:00,240 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17841  1.17807  1.17880  1.17800
# 8  1.17807  1.17866  1.17872  1.17767
# 2025-07-24 15:15:00,240 - INFO - Calculated TP/SL: TPBuy=1.18076, SLBuy=1.17761, TPSell=1.17656, SLSell=1.17971
# 2025-07-24 15:15:00,241 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:15:00,242 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:15:00,242 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:20:00 BST)" executed successfully
# 2025-07-24 15:20:00,005 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:25:00 BST)" (scheduled at 2025-07-24 15:20:00+01:00)
# 2025-07-24 15:20:00,006 - INFO - --- Trading job started ---
# 2025-07-24 15:20:00,007 - INFO - Current memory usage: 149.04 MB
# 2025-07-24 15:20:00,306 - INFO - setting up API-client for environment practice
# 2025-07-24 15:20:00,308 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17807  1.17866  1.17872  1.17767
# 8  1.17866  1.17802  1.17880  1.17797
# 2025-07-24 15:20:00,309 - INFO - Calculated TP/SL: TPBuy=1.17968, SLBuy=1.17719, TPSell=1.17636, SLSell=1.17885
# 2025-07-24 15:20:00,309 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:20:00,310 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:20:00,311 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:25:00 BST)" executed successfully
# 2025-07-24 15:25:00,002 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:30:00 BST)" (scheduled at 2025-07-24 15:25:00+01:00)
# 2025-07-24 15:25:00,003 - INFO - --- Trading job started ---
# 2025-07-24 15:25:00,004 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 15:25:00,209 - INFO - setting up API-client for environment practice
# 2025-07-24 15:25:00,211 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17866  1.17802  1.17880  1.17797
# 8  1.17802  1.17693  1.17805  1.17686
# 2025-07-24 15:25:00,211 - INFO - Calculated TP/SL: TPBuy=1.17931, SLBuy=1.17574, TPSell=1.17455, SLSell=1.17812
# 2025-07-24 15:25:00,212 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:25:00,212 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:25:00,213 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:30:00 BST)" executed successfully
# 2025-07-24 15:30:00,012 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:35:00 BST)" (scheduled at 2025-07-24 15:30:00+01:00)
# 2025-07-24 15:30:00,012 - INFO - --- Trading job started ---
# 2025-07-24 15:30:00,013 - INFO - Current memory usage: 149.03 MB
# 2025-07-24 15:30:00,218 - INFO - setting up API-client for environment practice
# 2025-07-24 15:30:00,220 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17802  1.17693  1.17805  1.17686
# 8  1.17693  1.17706  1.17714  1.17647
# 2025-07-24 15:30:00,221 - INFO - Calculated TP/SL: TPBuy=1.17841, SLBuy=1.17640, TPSell=1.17573, SLSell=1.17774
# 2025-07-24 15:30:00,221 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:30:00,222 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:30:00,222 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:35:00 BST)" executed successfully
# 2025-07-24 15:35:00,002 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:40:00 BST)" (scheduled at 2025-07-24 15:35:00+01:00)
# 2025-07-24 15:35:00,003 - INFO - --- Trading job started ---
# 2025-07-24 15:35:00,004 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 15:35:00,257 - INFO - setting up API-client for environment practice
# 2025-07-24 15:35:00,259 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17802  1.17693  1.17805  1.17686
# 8  1.17693  1.17706  1.17714  1.17647
# 2025-07-24 15:35:00,259 - INFO - Calculated TP/SL: TPBuy=1.17841, SLBuy=1.17640, TPSell=1.17573, SLSell=1.17774
# 2025-07-24 15:35:00,260 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:35:00,260 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:35:00,261 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:40:00 BST)" executed successfully
# 2025-07-24 15:40:00,013 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:45:00 BST)" (scheduled at 2025-07-24 15:40:00+01:00)
# 2025-07-24 15:40:00,014 - INFO - --- Trading job started ---
# 2025-07-24 15:40:00,015 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 15:40:00,265 - INFO - setting up API-client for environment practice
# 2025-07-24 15:40:00,267 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17707  1.17731  1.17748  1.17700
# 8  1.17731  1.17740  1.17775  1.17717
# 2025-07-24 15:40:00,267 - INFO - Calculated TP/SL: TPBuy=1.17857, SLBuy=1.17683, TPSell=1.17625, SLSell=1.17799
# 2025-07-24 15:40:00,268 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:40:00,268 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:40:00,270 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:45:00 BST)" executed successfully
# 2025-07-24 15:45:00,001 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:50:00 BST)" (scheduled at 2025-07-24 15:45:00+01:00)
# 2025-07-24 15:45:00,002 - INFO - --- Trading job started ---
# 2025-07-24 15:45:00,002 - INFO - Current memory usage: 149.03 MB
# 2025-07-24 15:45:00,237 - INFO - setting up API-client for environment practice
# 2025-07-24 15:45:00,239 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17731  1.17740  1.17775  1.17717
# 8  1.17741  1.17777  1.17788  1.17741
# 2025-07-24 15:45:00,239 - INFO - Calculated TP/SL: TPBuy=1.17872, SLBuy=1.17731, TPSell=1.17684, SLSell=1.17825
# 2025-07-24 15:45:00,240 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:45:00,241 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:45:00,242 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:50:00 BST)" executed successfully
# 2025-07-24 15:50:00,002 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:55:00 BST)" (scheduled at 2025-07-24 15:50:00+01:00)
# 2025-07-24 15:50:00,002 - INFO - --- Trading job started ---
# 2025-07-24 15:50:00,003 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 15:50:00,297 - INFO - setting up API-client for environment practice
# 2025-07-24 15:50:00,300 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17741  1.17777  1.17788  1.17741
# 8  1.17778  1.17788  1.17791  1.17747
# 2025-07-24 15:50:00,301 - INFO - Calculated TP/SL: TPBuy=1.17873, SLBuy=1.17741, TPSell=1.17697, SLSell=1.17829
# 2025-07-24 15:50:00,301 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:50:00,302 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:50:00,302 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 15:55:00 BST)" executed successfully
# 2025-07-24 15:55:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:00:00 BST)" (scheduled at 2025-07-24 15:55:00+01:00)
# 2025-07-24 15:55:00,008 - INFO - --- Trading job started ---
# 2025-07-24 15:55:00,009 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 15:55:00,260 - INFO - setting up API-client for environment practice
# 2025-07-24 15:55:00,262 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17778  1.17788  1.17791  1.17747
# 8  1.17785  1.17658  1.17799  1.17647
# 2025-07-24 15:55:00,262 - INFO - Calculated TP/SL: TPBuy=1.17962, SLBuy=1.17506, TPSell=1.17354, SLSell=1.17810
# 2025-07-24 15:55:00,263 - INFO - Generated Trading Signal: 0
# 2025-07-24 15:55:00,263 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 15:55:00,264 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:00:00 BST)" executed successfully
# 2025-07-24 16:00:00,005 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:05:00 BST)" (scheduled at 2025-07-24 16:00:00+01:00)
# 2025-07-24 16:00:00,006 - INFO - --- Trading job started ---
# 2025-07-24 16:00:00,006 - INFO - Current memory usage: 149.07 MB
# 2025-07-24 16:00:00,333 - INFO - setting up API-client for environment practice
# 2025-07-24 16:00:00,334 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17785  1.17658  1.17799  1.17647
# 8  1.17658  1.17655  1.17676  1.17607
# 2025-07-24 16:00:00,335 - INFO - Calculated TP/SL: TPBuy=1.17795, SLBuy=1.17588, TPSell=1.17519, SLSell=1.17726
# 2025-07-24 16:00:00,335 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:00:00,336 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:00:00,336 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:05:00 BST)" executed successfully
# 2025-07-24 16:05:00,008 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:10:00 BST)" (scheduled at 2025-07-24 16:05:00+01:00)
# 2025-07-24 16:05:00,010 - INFO - --- Trading job started ---
# 2025-07-24 16:05:00,010 - INFO - Current memory usage: 120.08 MB
# 2025-07-24 16:05:00,262 - INFO - setting up API-client for environment practice
# 2025-07-24 16:05:00,265 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17658  1.17655  1.17676  1.17607
# 8  1.17657  1.17637  1.17678  1.17624
# 2025-07-24 16:05:00,265 - INFO - Calculated TP/SL: TPBuy=1.17745, SLBuy=1.17583, TPSell=1.17529, SLSell=1.17691
# 2025-07-24 16:05:00,266 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:05:00,267 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:05:00,268 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:10:00 BST)" executed successfully
# 2025-07-24 16:10:00,005 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:15:00 BST)" (scheduled at 2025-07-24 16:10:00+01:00)
# 2025-07-24 16:10:00,006 - INFO - --- Trading job started ---
# 2025-07-24 16:10:00,007 - INFO - Current memory usage: 118.91 MB
# 2025-07-24 16:10:00,279 - INFO - setting up API-client for environment practice
# 2025-07-24 16:10:00,282 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17657  1.17637  1.17678  1.17624
# 8  1.17637  1.17651  1.17667  1.17619
# 2025-07-24 16:10:00,283 - INFO - Calculated TP/SL: TPBuy=1.17747, SLBuy=1.17603, TPSell=1.17555, SLSell=1.17699
# 2025-07-24 16:10:00,284 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:10:00,284 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:10:00,285 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:15:00 BST)" executed successfully
# 2025-07-24 16:15:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:20:00 BST)" (scheduled at 2025-07-24 16:15:00+01:00)
# 2025-07-24 16:15:00,009 - INFO - --- Trading job started ---
# 2025-07-24 16:15:00,010 - INFO - Current memory usage: 115.32 MB
# 2025-07-24 16:15:00,423 - INFO - setting up API-client for environment practice
# 2025-07-24 16:15:00,426 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17637  1.17651  1.17667  1.17619
# 8  1.17651  1.17577  1.17656  1.17575
# 2025-07-24 16:15:00,427 - INFO - Calculated TP/SL: TPBuy=1.17739, SLBuy=1.17496, TPSell=1.17415, SLSell=1.17658
# 2025-07-24 16:15:00,428 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:15:00,429 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:15:00,430 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:20:00 BST)" executed successfully
# 2025-07-24 16:20:00,001 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:25:00 BST)" (scheduled at 2025-07-24 16:20:00+01:00)
# 2025-07-24 16:20:00,003 - INFO - --- Trading job started ---
# 2025-07-24 16:20:00,004 - INFO - Current memory usage: 114.98 MB
# 2025-07-24 16:20:00,275 - INFO - setting up API-client for environment practice
# 2025-07-24 16:20:00,278 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17651  1.17577  1.17656  1.17575
# 8  1.17577  1.17634  1.17635  1.17546
# 2025-07-24 16:20:00,279 - INFO - Calculated TP/SL: TPBuy=1.17811, SLBuy=1.17544, TPSell=1.17455, SLSell=1.17722
# 2025-07-24 16:20:00,280 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:20:00,281 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:20:00,281 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:25:00 BST)" executed successfully
# 2025-07-24 16:25:00,006 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:30:00 BST)" (scheduled at 2025-07-24 16:25:00+01:00)
# 2025-07-24 16:25:00,008 - INFO - --- Trading job started ---
# 2025-07-24 16:25:00,009 - INFO - Current memory usage: 114.85 MB
# 2025-07-24 16:25:00,262 - INFO - setting up API-client for environment practice
# 2025-07-24 16:25:00,265 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17577  1.17634  1.17635  1.17546
# 8  1.17633  1.17698  1.17704  1.17629
# 2025-07-24 16:25:00,266 - INFO - Calculated TP/SL: TPBuy=1.17850, SLBuy=1.17625, TPSell=1.17550, SLSell=1.17775
# 2025-07-24 16:25:00,266 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:25:00,267 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:25:00,268 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:30:00 BST)" executed successfully
# 2025-07-24 16:30:00,014 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:35:00 BST)" (scheduled at 2025-07-24 16:30:00+01:00)
# 2025-07-24 16:30:00,016 - INFO - --- Trading job started ---
# 2025-07-24 16:30:00,017 - INFO - Current memory usage: 111.49 MB
# 2025-07-24 16:30:00,621 - INFO - setting up API-client for environment practice
# 2025-07-24 16:30:00,624 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17633  1.17698  1.17704  1.17629
# 8  1.17700  1.17750  1.17768  1.17700
# 2025-07-24 16:30:00,624 - INFO - Calculated TP/SL: TPBuy=1.17887, SLBuy=1.17683, TPSell=1.17615, SLSell=1.17819
# 2025-07-24 16:30:00,625 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:30:00,625 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:30:00,626 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:35:00 BST)" executed successfully
# 2025-07-24 16:35:00,004 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:40:00 BST)" (scheduled at 2025-07-24 16:35:00+01:00)
# 2025-07-24 16:35:00,005 - INFO - --- Trading job started ---
# 2025-07-24 16:35:00,006 - INFO - Current memory usage: 105.57 MB
# 2025-07-24 16:35:00,276 - INFO - setting up API-client for environment practice
# 2025-07-24 16:35:00,280 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17700  1.17750  1.17768  1.17700
# 8  1.17751  1.17759  1.17776  1.17721
# 2025-07-24 16:35:00,282 - INFO - Calculated TP/SL: TPBuy=1.17867, SLBuy=1.17702, TPSell=1.17647, SLSell=1.17812
# 2025-07-24 16:35:00,283 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:35:00,284 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:35:00,285 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:40:00 BST)" executed successfully
# 2025-07-24 16:40:00,001 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:45:00 BST)" (scheduled at 2025-07-24 16:40:00+01:00)
# 2025-07-24 16:40:00,003 - INFO - --- Trading job started ---
# 2025-07-24 16:40:00,004 - INFO - Current memory usage: 85.80 MB
# 2025-07-24 16:40:00,243 - INFO - setting up API-client for environment practice
# 2025-07-24 16:40:00,245 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17751  1.17759  1.17776  1.17721
# 8  1.17757  1.17645  1.17760  1.17630
# 2025-07-24 16:40:00,246 - INFO - Calculated TP/SL: TPBuy=1.17907, SLBuy=1.17517, TPSell=1.17387, SLSell=1.17777
# 2025-07-24 16:40:00,247 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:40:00,248 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:40:00,249 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:45:00 BST)" executed successfully
# 2025-07-24 16:45:00,010 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:50:00 BST)" (scheduled at 2025-07-24 16:45:00+01:00)
# 2025-07-24 16:45:00,012 - INFO - --- Trading job started ---
# 2025-07-24 16:45:00,012 - INFO - Current memory usage: 80.54 MB
# 2025-07-24 16:45:00,264 - INFO - setting up API-client for environment practice
# 2025-07-24 16:45:00,266 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17757  1.17645  1.17760  1.17630
# 8  1.17647  1.17655  1.17695  1.17632
# 2025-07-24 16:45:00,266 - INFO - Calculated TP/SL: TPBuy=1.17781, SLBuy=1.17592, TPSell=1.17529, SLSell=1.17718
# 2025-07-24 16:45:00,268 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:45:00,269 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:45:00,269 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:50:00 BST)" executed successfully
# 2025-07-24 16:50:00,008 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:55:00 BST)" (scheduled at 2025-07-24 16:50:00+01:00)
# 2025-07-24 16:50:00,010 - INFO - --- Trading job started ---
# 2025-07-24 16:50:00,011 - INFO - Current memory usage: 76.64 MB
# 2025-07-24 16:50:00,229 - INFO - setting up API-client for environment practice
# 2025-07-24 16:50:00,232 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17647  1.17655  1.17695  1.17632
# 8  1.17655  1.17674  1.17712  1.17645
# 2025-07-24 16:50:00,233 - INFO - Calculated TP/SL: TPBuy=1.17808, SLBuy=1.17607, TPSell=1.17540, SLSell=1.17741
# 2025-07-24 16:50:00,235 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:50:00,235 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:50:00,236 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 16:55:00 BST)" executed successfully
# 2025-07-24 16:55:00,005 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:00:00 BST)" (scheduled at 2025-07-24 16:55:00+01:00)
# 2025-07-24 16:55:00,007 - INFO - --- Trading job started ---
# 2025-07-24 16:55:00,008 - INFO - Current memory usage: 74.66 MB
# 2025-07-24 16:55:00,361 - INFO - setting up API-client for environment practice
# 2025-07-24 16:55:00,364 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17655  1.17674  1.17712  1.17645
# 8  1.17674  1.17691  1.17694  1.17658
# 2025-07-24 16:55:00,365 - INFO - Calculated TP/SL: TPBuy=1.17764, SLBuy=1.17656, TPSell=1.17620, SLSell=1.17728
# 2025-07-24 16:55:00,365 - INFO - Generated Trading Signal: 0
# 2025-07-24 16:55:00,366 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 16:55:00,367 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:00:00 BST)" executed successfully
# 2025-07-24 17:00:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:05:00 BST)" (scheduled at 2025-07-24 17:00:00+01:00)
# 2025-07-24 17:00:00,009 - INFO - --- Trading job started ---
# 2025-07-24 17:00:00,010 - INFO - Current memory usage: 72.64 MB
# 2025-07-24 17:00:00,313 - INFO - setting up API-client for environment practice
# 2025-07-24 17:00:00,315 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17674  1.17691  1.17694  1.17658
# 8  1.17692  1.17640  1.17701  1.17636
# 2025-07-24 17:00:00,316 - INFO - Calculated TP/SL: TPBuy=1.17771, SLBuy=1.17576, TPSell=1.17511, SLSell=1.17706
# 2025-07-24 17:00:00,317 - INFO - Generated Trading Signal: 2
# 2025-07-24 17:00:00,317 - INFO - BUY signal detected. Attempting to place order.
# 2025-07-24 17:00:00,318 - INFO - performing request https://api-fxpractice.oanda.com/v3/accounts/101-004-35883351-001/orders
# 2025-07-24 17:00:00,490 - INFO - Buy Order Response: {'orderCreateTransaction': {'id': '245', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '245', 'requestID': '61397374083668211', 'time': '2025-07-24T16:00:01.609186987Z', 'type': 'MARKET_ORDER', 'instrument': 'EUR_USD', 'units': '1000', 'timeInForce': 'FOK', 'positionFill': 'DEFAULT', 'takeProfitOnFill': {'price': '1.17771', 'timeInForce': 'GTC'}, 'stopLossOnFill': {'price': '1.17576', 'timeInForce': 'GTC', 'triggerMode': 'TOP_OF_BOOK'}, 'reason': 'CLIENT_ORDER'}, 'orderFillTransaction': {'id': '246', 'accountID': '101-004-35883351-001', 'userID': 35883351, 'batchID': '245', 'requestID': '61397374083668211', 'time': '2025-07-24T16:00:01.609186987Z', 'type': 'ORDER_FILL', 'orderID': '245', 'instrument': 'EUR_USD', 'units': '1000', 'requestedUnits': '1000', 'price': '1.17643', 'pl': '1.4716', 'quotePL': '2.00000', 'financing': '0.0000', 'baseFinancing': '0.00000000000000', 'commission': '0.0000', 'accountBalance': '100007.5785', 'gainQuoteHomeConversionFactor': '0.73582157284', 'lossQuoteHomeConversionFactor': '0.743216764527', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0333', 'fullVWAP': '1.17643', 'reason': 'MARKET_ORDER', 'tradesClosed': [{'tradeID': '242', 'units': '1000', 'realizedPL': '1.4716', 'financing': '0.0000', 'baseFinancing': '0.00000000000000', 'price': '1.17643', 'guaranteedExecutionFee': '0.0000', 'quoteGuaranteedExecutionFee': '0', 'halfSpreadCost': '0.0333'}], 'fullPrice': {'closeoutBid': '1.17625', 'closeoutAsk': '1.17653', 'timestamp': '2025-07-24T16:00:01.021953614Z', 'bids': [{'price': '1.17634', 'liquidity': '500000'}, {'price': '1.17633', 'liquidity': '500000'}, {'price': '1.17632', 'liquidity': '2000000'}, {'price': '1.17631', 'liquidity': '2000000'}, {'price': '1.17630', 'liquidity': '5000000'}, {'price': '1.17628', 'liquidity': '10000000'}, {'price': '1.17625', 'liquidity': '10000000'}], 'asks': [{'price': '1.17643', 'liquidity': '500000'}, {'price': '1.17645', 'liquidity': '2500000'}, {'price': '1.17646', 'liquidity': '2000000'}, {'price': '1.17647', 'liquidity': '5000000'}, {'price': '1.17650', 'liquidity': '10000000'}, {'price': '1.17653', 'liquidity': '10000000'}]}, 'homeConversionFactors': {'gainQuoteHome': {'factor': '0.73582157284008'}, 'lossQuoteHome': {'factor': '0.74321676452692'}, 'gainBaseHome': {'factor': '0.86563010'}, 'lossBaseHome': {'factor': '0.87432990'}}}, 'relatedTransactionIDs': ['245', '246', '247', '248'], 'lastTransactionID': '248'}
# 2025-07-24 17:00:00,491 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:05:00 BST)" executed successfully
# 2025-07-24 17:05:00,015 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:10:00 BST)" (scheduled at 2025-07-24 17:05:00+01:00)
# 2025-07-24 17:05:00,016 - INFO - --- Trading job started ---
# 2025-07-24 17:05:00,017 - INFO - Current memory usage: 66.60 MB
# 2025-07-24 17:05:00,251 - INFO - setting up API-client for environment practice
# 2025-07-24 17:05:00,256 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17692  1.17640  1.17701  1.17636
# 8  1.17641  1.17663  1.17668  1.17618
# 2025-07-24 17:05:00,257 - INFO - Calculated TP/SL: TPBuy=1.17763, SLBuy=1.17613, TPSell=1.17563, SLSell=1.17713
# 2025-07-24 17:05:00,258 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:05:00,259 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:05:00,260 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:10:00 BST)" executed successfully
# 2025-07-24 17:10:00,010 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:15:00 BST)" (scheduled at 2025-07-24 17:10:00+01:00)
# 2025-07-24 17:10:00,011 - INFO - --- Trading job started ---
# 2025-07-24 17:10:00,012 - INFO - Current memory usage: 66.61 MB
# 2025-07-24 17:10:00,211 - INFO - setting up API-client for environment practice
# 2025-07-24 17:10:00,215 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17641  1.17663  1.17668  1.17618
# 8  1.17663  1.17710  1.17719  1.17661
# 2025-07-24 17:10:00,216 - INFO - Calculated TP/SL: TPBuy=1.17825, SLBuy=1.17651, TPSell=1.17593, SLSell=1.17767
# 2025-07-24 17:10:00,217 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:10:00,217 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:10:00,218 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:15:00 BST)" executed successfully
# 2025-07-24 17:15:00,003 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:20:00 BST)" (scheduled at 2025-07-24 17:15:00+01:00)
# 2025-07-24 17:15:00,004 - INFO - --- Trading job started ---
# 2025-07-24 17:15:00,005 - INFO - Current memory usage: 66.55 MB
# 2025-07-24 17:15:00,223 - INFO - setting up API-client for environment practice
# 2025-07-24 17:15:00,227 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17663  1.17710  1.17719  1.17661
# 8  1.17709  1.17648  1.17716  1.17646
# 2025-07-24 17:15:00,228 - INFO - Calculated TP/SL: TPBuy=1.17787, SLBuy=1.17577, TPSell=1.17507, SLSell=1.17717
# 2025-07-24 17:15:00,228 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:15:00,229 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:15:00,230 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:20:00 BST)" executed successfully
# 2025-07-24 17:20:00,006 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:25:00 BST)" (scheduled at 2025-07-24 17:20:00+01:00)
# 2025-07-24 17:20:00,007 - INFO - --- Trading job started ---
# 2025-07-24 17:20:00,008 - INFO - Current memory usage: 66.67 MB
# 2025-07-24 17:20:00,783 - INFO - setting up API-client for environment practice
# 2025-07-24 17:20:00,787 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17709  1.17648  1.17716  1.17646
# 8  1.17647  1.17636  1.17668  1.17629
# 2025-07-24 17:20:00,788 - INFO - Calculated TP/SL: TPBuy=1.17712, SLBuy=1.17595, TPSell=1.17556, SLSell=1.17673
# 2025-07-24 17:20:00,789 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:20:00,790 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:20:00,791 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:25:00 BST)" executed successfully
# 2025-07-24 17:25:00,008 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:30:00 BST)" (scheduled at 2025-07-24 17:25:00+01:00)
# 2025-07-24 17:25:00,009 - INFO - --- Trading job started ---
# 2025-07-24 17:25:00,010 - INFO - Current memory usage: 66.70 MB
# 2025-07-24 17:25:00,367 - INFO - setting up API-client for environment practice
# 2025-07-24 17:25:00,371 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17647  1.17636  1.17668  1.17629
# 8  1.17634  1.17601  1.17639  1.17589
# 2025-07-24 17:25:00,372 - INFO - Calculated TP/SL: TPBuy=1.17702, SLBuy=1.17552, TPSell=1.17502, SLSell=1.17652
# 2025-07-24 17:25:00,373 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:25:00,373 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:25:00,374 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:30:00 BST)" executed successfully
# 2025-07-24 17:30:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:35:00 BST)" (scheduled at 2025-07-24 17:30:00+01:00)
# 2025-07-24 17:30:00,008 - INFO - --- Trading job started ---
# 2025-07-24 17:30:00,008 - INFO - Current memory usage: 66.71 MB
# 2025-07-24 17:30:00,410 - INFO - setting up API-client for environment practice
# 2025-07-24 17:30:00,413 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17634  1.17601  1.17639  1.17589
# 8  1.17602  1.17590  1.17612  1.17560
# 2025-07-24 17:30:00,414 - INFO - Calculated TP/SL: TPBuy=1.17695, SLBuy=1.17539, TPSell=1.17487, SLSell=1.17643
# 2025-07-24 17:30:00,414 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:30:00,415 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:30:00,415 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:35:00 BST)" executed successfully
# 2025-07-24 17:35:00,015 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:40:00 BST)" (scheduled at 2025-07-24 17:35:00+01:00)
# 2025-07-24 17:35:00,017 - INFO - --- Trading job started ---
# 2025-07-24 17:35:00,018 - INFO - Current memory usage: 66.66 MB
# 2025-07-24 17:35:00,341 - INFO - setting up API-client for environment practice
# 2025-07-24 17:35:00,344 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17602  1.17590  1.17612  1.17560
# 8  1.17591  1.17625  1.17637  1.17589
# 2025-07-24 17:35:00,345 - INFO - Calculated TP/SL: TPBuy=1.17723, SLBuy=1.17579, TPSell=1.17531, SLSell=1.17675
# 2025-07-24 17:35:00,346 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:35:00,346 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:35:00,347 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:40:00 BST)" executed successfully
# 2025-07-24 17:40:00,011 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:45:00 BST)" (scheduled at 2025-07-24 17:40:00+01:00)
# 2025-07-24 17:40:00,013 - INFO - --- Trading job started ---
# 2025-07-24 17:40:00,015 - INFO - Current memory usage: 66.26 MB
# 2025-07-24 17:40:00,249 - INFO - setting up API-client for environment practice
# 2025-07-24 17:40:00,251 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17591  1.17625  1.17637  1.17589
# 8  1.17627  1.17623  1.17633  1.17605
# 2025-07-24 17:40:00,252 - INFO - Calculated TP/SL: TPBuy=1.17679, SLBuy=1.17595, TPSell=1.17567, SLSell=1.17651
# 2025-07-24 17:40:00,253 - INFO - Generated Trading Signal: 0
# 2025-07-24 17:40:00,254 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-24 17:40:00,255 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:45:00 BST)" executed successfully
# 2025-07-24 17:45:00,011 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-24 17:50:00 BST)" (scheduled at 2025-07-24 17:45:00+01:00)
# 2025-07-24 17:45:00,012 - INFO - --- Trading job started ---
# 2025-07-24 17:45:00,013 - INFO - Current memory usage: 65.89 MB
# 2025-07-24 17:45:00,504 - INFO - setting up API-client for environment practice
# ...
# 2025-07-25 14:50:00,274 - INFO - Calculated TP/SL: TPBuy=1.17321, SLBuy=1.16946, TPSell=1.16821, SLSell=1.17196
# 2025-07-25 14:50:00,275 - INFO - Generated Trading Signal: 0
# 2025-07-25 14:50:00,276 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 14:50:00,277 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 14:55:00 BST)" executed successfully
# 2025-07-25 14:55:00,003 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:00:00 BST)" (scheduled at 2025-07-25 14:55:00+01:00)
# 2025-07-25 14:55:00,004 - INFO - --- Trading job started ---
# 2025-07-25 14:55:00,005 - INFO - Current memory usage: 62.08 MB
# 2025-07-25 14:55:00,255 - INFO - setting up API-client for environment practice
# 2025-07-25 14:55:00,257 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17143  1.17071  1.17170  1.17045
# 8  1.17071  1.17104  1.17139  1.17062
# 2025-07-25 14:55:00,258 - INFO - Calculated TP/SL: TPBuy=1.17257, SLBuy=1.17026, TPSell=1.16949, SLSell=1.17180
# 2025-07-25 14:55:00,258 - INFO - Generated Trading Signal: 0
# 2025-07-25 14:55:00,259 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 14:55:00,259 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:00:00 BST)" executed successfully
# 2025-07-25 15:00:00,004 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:05:00 BST)" (scheduled at 2025-07-25 15:00:00+01:00)
# 2025-07-25 15:00:00,005 - INFO - --- Trading job started ---
# 2025-07-25 15:00:00,006 - INFO - Current memory usage: 62.12 MB
# 2025-07-25 15:00:00,258 - INFO - setting up API-client for environment practice
# 2025-07-25 15:00:00,260 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17071  1.17104  1.17139  1.17062
# 8  1.17103  1.17183  1.17197  1.17094
# 2025-07-25 15:00:00,261 - INFO - Calculated TP/SL: TPBuy=1.17390, SLBuy=1.17081, TPSell=1.16978, SLSell=1.17287
# 2025-07-25 15:00:00,261 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:00:00,262 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:00:00,263 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:05:00 BST)" executed successfully
# 2025-07-25 15:05:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:10:00 BST)" (scheduled at 2025-07-25 15:05:00+01:00)
# 2025-07-25 15:05:00,008 - INFO - --- Trading job started ---
# 2025-07-25 15:05:00,009 - INFO - Current memory usage: 62.11 MB
# 2025-07-25 15:05:00,248 - INFO - setting up API-client for environment practice
# 2025-07-25 15:05:00,250 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17103  1.17183  1.17197  1.17094
# 8  1.17184  1.17210  1.17222  1.17160
# 2025-07-25 15:05:00,250 - INFO - Calculated TP/SL: TPBuy=1.17334, SLBuy=1.17148, TPSell=1.17086, SLSell=1.17272
# 2025-07-25 15:05:00,251 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:05:00,252 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:05:00,253 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:10:00 BST)" executed successfully
# 2025-07-25 15:10:00,008 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:15:00 BST)" (scheduled at 2025-07-25 15:10:00+01:00)
# 2025-07-25 15:10:00,009 - INFO - --- Trading job started ---
# 2025-07-25 15:10:00,010 - INFO - Current memory usage: 62.10 MB
# 2025-07-25 15:10:00,242 - INFO - setting up API-client for environment practice
# 2025-07-25 15:10:00,244 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17184  1.17210  1.17222  1.17160
# 8  1.17210  1.17237  1.17279  1.17208
# 2025-07-25 15:10:00,244 - INFO - Calculated TP/SL: TPBuy=1.17379, SLBuy=1.17166, TPSell=1.17095, SLSell=1.17308
# 2025-07-25 15:10:00,245 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:10:00,246 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:10:00,247 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:15:00 BST)" executed successfully
# 2025-07-25 15:15:00,012 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:20:00 BST)" (scheduled at 2025-07-25 15:15:00+01:00)
# 2025-07-25 15:15:00,013 - INFO - --- Trading job started ---
# 2025-07-25 15:15:00,014 - INFO - Current memory usage: 62.09 MB
# 2025-07-25 15:15:00,332 - INFO - setting up API-client for environment practice
# 2025-07-25 15:15:00,335 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17237  1.17268  1.17294  1.17228
# 8  1.17268  1.17273  1.17289  1.17241
# 2025-07-25 15:15:00,336 - INFO - Calculated TP/SL: TPBuy=1.17368, SLBuy=1.17224, TPSell=1.17176, SLSell=1.17320
# 2025-07-25 15:15:00,336 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:15:00,337 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:15:00,337 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:20:00 BST)" executed successfully
# 2025-07-25 15:20:00,014 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:25:00 BST)" (scheduled at 2025-07-25 15:20:00+01:00)
# 2025-07-25 15:20:00,015 - INFO - --- Trading job started ---
# 2025-07-25 15:20:00,016 - INFO - Current memory usage: 62.08 MB
# 2025-07-25 15:20:00,299 - INFO - setting up API-client for environment practice
# 2025-07-25 15:20:00,301 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17268  1.17273  1.17289  1.17241
# 8  1.17272  1.17316  1.17319  1.17263
# 2025-07-25 15:20:00,301 - INFO - Calculated TP/SL: TPBuy=1.17427, SLBuy=1.17259, TPSell=1.17203, SLSell=1.17371
# 2025-07-25 15:20:00,303 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:20:00,303 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:20:00,304 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:25:00 BST)" executed successfully
# 2025-07-25 15:25:00,009 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:30:00 BST)" (scheduled at 2025-07-25 15:25:00+01:00)
# 2025-07-25 15:25:00,010 - INFO - --- Trading job started ---
# 2025-07-25 15:25:00,011 - INFO - Current memory usage: 62.08 MB
# 2025-07-25 15:25:00,243 - INFO - setting up API-client for environment practice
# 2025-07-25 15:25:00,245 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17268  1.17273  1.17289  1.17241
# 8  1.17272  1.17316  1.17319  1.17263
# 2025-07-25 15:25:00,246 - INFO - Calculated TP/SL: TPBuy=1.17427, SLBuy=1.17259, TPSell=1.17203, SLSell=1.17371
# 2025-07-25 15:25:00,247 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:25:00,248 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:25:00,248 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:30:00 BST)" executed successfully
# 2025-07-25 15:30:00,002 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:35:00 BST)" (scheduled at 2025-07-25 15:30:00+01:00)
# 2025-07-25 15:30:00,003 - INFO - --- Trading job started ---
# 2025-07-25 15:30:00,004 - INFO - Current memory usage: 62.09 MB
# 2025-07-25 15:30:00,399 - INFO - setting up API-client for environment practice
# 2025-07-25 15:30:00,401 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17315  1.17345  1.17348  1.17273
# 8  1.17344  1.17327  1.17349  1.17322
# 2025-07-25 15:30:00,401 - INFO - Calculated TP/SL: TPBuy=1.17380, SLBuy=1.17299, TPSell=1.17272, SLSell=1.17353
# 2025-07-25 15:30:00,402 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:30:00,403 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:30:00,404 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:35:00 BST)" executed successfully
# 2025-07-25 15:35:00,012 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:40:00 BST)" (scheduled at 2025-07-25 15:35:00+01:00)
# 2025-07-25 15:35:00,013 - INFO - --- Trading job started ---
# 2025-07-25 15:35:00,014 - INFO - Current memory usage: 62.11 MB
# 2025-07-25 15:35:00,297 - INFO - setting up API-client for environment practice
# 2025-07-25 15:35:00,300 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17344  1.17327  1.17349  1.17322
# 8  1.17326  1.17293  1.17330  1.17274
# 2025-07-25 15:35:00,301 - INFO - Calculated TP/SL: TPBuy=1.17405, SLBuy=1.17237, TPSell=1.17181, SLSell=1.17349
# 2025-07-25 15:35:00,301 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:35:00,302 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:35:00,303 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:40:00 BST)" executed successfully
# 2025-07-25 15:40:00,008 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:45:00 BST)" (scheduled at 2025-07-25 15:40:00+01:00)
# 2025-07-25 15:40:00,009 - INFO - --- Trading job started ---
# 2025-07-25 15:40:00,010 - INFO - Current memory usage: 62.10 MB
# 2025-07-25 15:40:00,275 - INFO - setting up API-client for environment practice
# 2025-07-25 15:40:00,278 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17326  1.17293  1.17330  1.17274
# 8  1.17293  1.17300  1.17339  1.17291
# 2025-07-25 15:40:00,278 - INFO - Calculated TP/SL: TPBuy=1.17395, SLBuy=1.17251, TPSell=1.17203, SLSell=1.17347
# 2025-07-25 15:40:00,279 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:40:00,279 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:40:00,280 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:45:00 BST)" executed successfully
# 2025-07-25 15:45:00,014 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:50:00 BST)" (scheduled at 2025-07-25 15:45:00+01:00)
# 2025-07-25 15:45:00,016 - INFO - --- Trading job started ---
# 2025-07-25 15:45:00,017 - INFO - Current memory usage: 62.11 MB
# 2025-07-25 15:45:00,564 - INFO - setting up API-client for environment practice
# 2025-07-25 15:45:00,566 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17293  1.17300  1.17339  1.17291
# 8  1.17299  1.17298  1.17314  1.17258
# 2025-07-25 15:45:00,567 - INFO - Calculated TP/SL: TPBuy=1.17410, SLBuy=1.17242, TPSell=1.17186, SLSell=1.17354
# 2025-07-25 15:45:00,568 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:45:00,569 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:45:00,569 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:50:00 BST)" executed successfully
# 2025-07-25 15:50:00,007 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:55:00 BST)" (scheduled at 2025-07-25 15:50:00+01:00)
# 2025-07-25 15:50:00,008 - INFO - --- Trading job started ---
# 2025-07-25 15:50:00,008 - INFO - Current memory usage: 62.05 MB
# 2025-07-25 15:50:00,288 - INFO - setting up API-client for environment practice
# 2025-07-25 15:50:00,291 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17299  1.17298  1.17314  1.17258
# 8  1.17298  1.17291  1.17322  1.17282
# 2025-07-25 15:50:00,291 - INFO - Calculated TP/SL: TPBuy=1.17369, SLBuy=1.17249, TPSell=1.17209, SLSell=1.17329
# 2025-07-25 15:50:00,292 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:50:00,292 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:50:00,294 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 15:55:00 BST)" executed successfully
# 2025-07-25 15:55:00,011 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:00:00 BST)" (scheduled at 2025-07-25 15:55:00+01:00)
# 2025-07-25 15:55:00,012 - INFO - --- Trading job started ---
# 2025-07-25 15:55:00,013 - INFO - Current memory usage: 62.07 MB
# 2025-07-25 15:55:00,273 - INFO - setting up API-client for environment practice
# 2025-07-25 15:55:00,275 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17298  1.17291  1.17322  1.17282
# 8  1.17289  1.17269  1.17295  1.17259
# 2025-07-25 15:55:00,275 - INFO - Calculated TP/SL: TPBuy=1.17341, SLBuy=1.17233, TPSell=1.17197, SLSell=1.17305
# 2025-07-25 15:55:00,276 - INFO - Generated Trading Signal: 0
# 2025-07-25 15:55:00,276 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 15:55:00,277 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:00:00 BST)" executed successfully
# 2025-07-25 16:00:00,010 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:05:00 BST)" (scheduled at 2025-07-25 16:00:00+01:00)
# 2025-07-25 16:00:00,011 - INFO - --- Trading job started ---
# 2025-07-25 16:00:00,012 - INFO - Current memory usage: 62.08 MB
# 2025-07-25 16:00:00,627 - INFO - setting up API-client for environment practice
# 2025-07-25 16:00:00,630 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17289  1.17269  1.17295  1.17259
# 8  1.17269  1.17288  1.17303  1.17264
# 2025-07-25 16:00:00,630 - INFO - Calculated TP/SL: TPBuy=1.17363, SLBuy=1.17246, TPSell=1.17207, SLSell=1.17324
# 2025-07-25 16:00:00,631 - INFO - Generated Trading Signal: 0
# 2025-07-25 16:00:00,632 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 16:00:00,633 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:05:00 BST)" executed successfully
# 2025-07-25 16:05:00,005 - INFO - Running job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:10:00 BST)" (scheduled at 2025-07-25 16:05:00+01:00)
# 2025-07-25 16:05:00,006 - INFO - --- Trading job started ---
# 2025-07-25 16:05:00,007 - INFO - Current memory usage: 62.09 MB
# 2025-07-25 16:05:00,381 - INFO - setting up API-client for environment practice
# 2025-07-25 16:05:00,383 - INFO - DataFrame for signal (last 2 candles shown):\n      Open    Close     High      Low
# 7  1.17269  1.17288  1.17303  1.17264
# 8  1.17285  1.17289  1.17303  1.17275
# 2025-07-25 16:05:00,383 - INFO - Calculated TP/SL: TPBuy=1.17345, SLBuy=1.17261, TPSell=1.17233, SLSell=1.17317
# 2025-07-25 16:05:00,385 - INFO - Generated Trading Signal: 0
# 2025-07-25 16:05:00,385 - INFO - No actionable trading signal (0). No order placed.
# 2025-07-25 16:05:00,386 - INFO - Job "trading_job (trigger: cron[day_of_week='mon-fri', hour='0-23', minute='*/5'], next run at: 2025-07-25 16:10:00 BST)" executed successfully
